# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
# Import dependencies
from pprint import pprint
from pymongo import MongoClient
mongo = MongoClient(port = 27017)
import pandas as pd

# %%
# Create an instance of MongoClient
mongo = MongoClient(port = 27017)

# %%
# assign the uk_food database to a variable name
db= mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['restaurant', 'establishments', 'establishments_list']

# %%
# assign the collection to a variable
establishment=db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
# Find the establishments with a hygiene score of 20

query = {'scores.Hygiene': 20}
# Use count_documents to display the number of documents in the result
print(establishment.count_documents(query))
# Display the first document in the results using pprint
establishment.find_one(query)
# Out:
# 41
# {'_id': ObjectId('641272bdd2b9535281a4e0b5'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': '0',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': 0.27694, 'latitude': 50.769705},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
# ...

# %%
# Convert the result to a Pandas DataFrame
hyg_20=establishment.find(query)
hyg_20_df =pd.DataFrame(hyg_20)
# Display the number of rows in the DataFrame
print(hyg_20_df.shape[0])
# Display the first 10 rows of the DataFrame
hyg_20_df.head(10)
# Out:
# 41
#                         _id   FHRSID  ChangesByServerID  \
# 0  641272bdd2b9535281a4e0b5   110681                  0
# 1  641272bdd2b9535281a4e433   612039                  0
# 2  641272bdd2b9535281a4e737   730933                  0
# 3  641272bdd2b9535281a4e92b   172735                  0
# 4  641272bdd2b9535281a4e93c   172953                  0
# 5  641272bdd2b9535281a4f2d8   512854                  0
# 6  641272bdd2b9535281a4f4fa  1537089                  0
# 7  641272bdd2b9535281a50a22   155648                  0
# 8  641272bdd2b9535281a50e6b  1012883                  0
# 9  641272bdd2b9535281a5167c   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# ...

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
localauth_query = {'LocalAuthorityName': {'$regex': "London"},
                          'RatingValue': {'$gte':'4'}
                          
                         }
              

# Use count_documents to display the number of documents in the result
print(establishment.count_documents(localauth_query))
# Display the first document in the results using pprint
pprint.pprint(establishment.find_one(localauth_query))
# Out:
# 34
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22440\2336299640.py in <module>
#       9 print(establishment.count_documents(localauth_query))
#      10 # Display the first document in the results using pprint
# ---> 11 pprint.pprint(establishment.find_one(localauth_query))
#
# AttributeError: 'function' object has no attribute 'pprint'

# %%
store_localauth=establishment.find(localauth_query)

# %%
# Convert the result to a Pandas DataFrame
local_auth_df = pd.DataFrame(store_localauth)
# Display the number of rows in the DataFrame
print("Number of rows in result: ", len(local_auth_df))
# Display the first 10 rows of the DataFrame
local_auth_df.head(10)
# Out:
# Number of rows in result:  34
#                         _id   FHRSID  ChangesByServerID  \
# 0  641272bdd2b9535281a4fac7   621707                  0
# 1  641272bdd2b9535281a4fdf2  1130836                  0
# 2  641272bdd2b9535281a50941   293783                  0
# 3  641272bdd2b9535281a5173e  1315095                  0
# 4  641272bdd2b9535281a51742   294474                  0
# 5  641272bdd2b9535281a51e48   294900                  0
# 6  641272bdd2b9535281a53f4e  1252616                  0
# 7  641272bdd2b9535281a53f56   293756                  0
# 8  641272bed2b9535281a5431b   878523                  0
# 9  641272bed2b9535281a54337   293772                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# ...

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of '5', sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score  

# degree_search = 0.01
degree_search = 0.01
latitude = 51.49014200
longitude = 0.08384000
query = {'geocode.latitude': {'$gte':latitude-degree_search, '$lte':latitude+degree_search},
         'geocode.longitude': {'$gte': longitude-degree_search, '$lte': longitude+degree_search},
         'RatingValue': '5'
         }



#Sort values by lowest hygiene score 
results = establishment.find(query).sort([('hygiene',1)]).limit(5)





                          
                          




# Print the results
pprint(list(results))
# Out:
# [{'AddressLine1': '130 - 132 Plumstead High Street',
#   'AddressLine2': '',
#   'AddressLine3': 'Plumstead',
#   'AddressLine4': 'Greenwich',
#   'BusinessName': 'Volunteer',
#   'BusinessType': 'Pub/bar/nightclub',
#   'BusinessTypeID': 7843,
#   'ChangesByServerID': 0,
#   'Distance': 4646.965634598608,
#   'FHRSID': 694609,
#   'LocalAuthorityBusinessID': 'PI/000116619',
#   'LocalAuthorityCode': '511',
#   'LocalAuthorityEmailAddress': 'health@royalgreenwich.gov.uk',
#   'LocalAuthorityName': 'Greenwich',
#   'LocalAuthorityWebSite': 'http://www.royalgreenwich.gov.uk',
#   'NewRatingPending': False,
#   'Phone': '',
#   'PostCode': 'SE18 1JQ',
#   'RatingDate': '2019-08-05T00:00:00',
#   'RatingKey': 'fhrs_5_en-gb',
#   'RatingValue': '5',
#   'RightToReply': '',
#   'SchemeType': 'FHRS',
#   '_id': ObjectId('641272bdd2b9535281a5391d'),
#   'geocode': {'latitude': 51.4873437, 'longitude': 0.09208},
#   'links': [{'href': 'http://api.ratings.food.gov.uk/establishments/694609',
# ...

# %%
# Convert result to Pandas DataFrame
results_df = pd.DataFrame(list(results))

#print results
results_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that: 
# 1. Matches establishments with a hygiene score of 0
match_query = {'$match': {'hygiene': {'$eq': 0}}}
# 2. Groups the matches by Local Authority
group_query= {'$group': {'id':{'LocalAuthorityBusinessID': '$LocalAuthorityBusinessID',
                         "hygiene": "$hygiene"}}}
                                
# 3. Sorts the matches from highest to lowest
sort_values={'$sort': {'hygiene':1}}

#put pipeline together 
pipeline=[group_query,match_query,sort_values]


# Print the number of documents in the result

# Print the first 10 results
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22440\420695646.py in <module>
#      13
#      14 # Print the number of documents in the result
# ---> 15 print(establishment.count_documents(pipeline))
#      16 # Print the first 10 results
#
# c:\Users\Kayla Bailey\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in count_documents(self, filter, session, **kwargs)
#    1719
#    1720         return self.__database.client._retryable_read(
# -> 1721             _cmd, self._read_preference_for(session), session)
#    1722
#    1723     def count(self, filter=None, session=None, **kwargs):
#
# c:\Users\Kayla Bailey\anaconda3\envs\PythonData\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
# ...

# %%
results = list(establishment.aggregate(pipeline))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22440\3401000999.py in <module>
# ----> 1 results = list(establishment.aggregate(pipeline))
#
# c:\Users\Kayla Bailey\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in aggregate(self, pipeline, session, **kwargs)
#    2378                                    session=s,
#    2379                                    explicit_session=session is not None,
# -> 2380                                    **kwargs)
#    2381
#    2382     def aggregate_raw_batches(self, pipeline, **kwargs):
#
# c:\Users\Kayla Bailey\anaconda3\envs\PythonData\lib\site-packages\pymongo\collection.py in _aggregate(self, aggregation_command, pipeline, cursor_class, session, explicit_session, **kwargs)
#    2297         return self.__database.client._retryable_read(
# ...

# %%
# Convert the result to a Pandas DataFrame
pd.DataFrame()
# Display the number of rows in the DataFrame
print("Number of result :",len())
# Display the first 10 rows of the DataFrame
pprint([0:10])
# Out:
#   File "C:\Users\Kayla Bailey\AppData\Local\Temp\ipykernel_22440\2705161606.py", line 6
#     pprint([0:10])
#              ^
# SyntaxError: invalid syntax
